# %% [markdown]
# # Data Set Information:
#
# This archive contains 2075259 measurements gathered in a house located in Sceaux (7km of Paris, France) between December 2006 and November 2010 (47 months).
#
# Notes:
#
# 1.(global_active_power*1000/60 - sub_metering_1 - sub_metering_2 - sub_metering_3) represents the active energy consumed every minute (in watt hour) in the household by electrical equipment not measured in sub-meterings 1, 2 and 3.
#
# 2.The dataset contains some missing values in the measurements (nearly 1,25% of the rows). All calendar timestamps are present in the dataset but for some timestamps, the measurement values are missing: a missing value is represented by the absence of value between two consecutive semi-colon attribute separators. For instance, the dataset shows missing values on April 28, 2007.

# %% [markdown]
# # Attribute Information:
#
# - 1.date: Date in format dd/mm/yyyy
#
# - 2.time: time in format hh:mm:ss
#
# - 3.global_active_power: household global minute-averaged active power (in kilowatt)
#
# - 4.global_reactive_power: household global minute-averaged reactive power (in kilowatt)
#
# - 5.voltage: minute-averaged voltage (in volt)
#
# - 6.global_intensity: household global minute-averaged current intensity (in ampere)
#
# - 7.sub_metering_1: energy sub-metering No. 1 (in watt-hour of active energy). It corresponds to the kitchen, containing mainly a dishwasher, an oven and a microwave (hot plates are not electric but gas powered)
# .
# - 8.sub_metering_2: energy sub-metering No. 2 (in watt-hour of active energy). It corresponds to the laundry room, containing a washing-machine, a tumble-drier, a refrigerator and a light.
#
# - 9.sub_metering_3: energy sub-metering No. 3 (in watt-hour of active energy). It corresponds to an electric water-heater and an air-conditioner.

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Data Ingestion

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1.Data Cleaning.ipynb',
#  '2.EDA.ipynb',
#  '3.Model Building.ipynb',
#  'Data',
#  'Std_scaler.joblib']

# %%
df=pd.read_csv("Data\household_power_consumption.txt",sep=";")
df.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    object
#  3   Global_reactive_power  object
#  4   Voltage                object
#  5   Global_intensity       object
#  6   Sub_metering_1         object
#  7   Sub_metering_2         object
#  8   Sub_metering_3         float64
# dtypes: float64(1), object(8)
# memory usage: 142.5+ MB

# %%
df.shape
# Out:
# (2075259, 9)

# %%
df.isna().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power          0
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Sub_metering_1               0
# Sub_metering_2               0
# Sub_metering_3           25979
# dtype: int64

# %%
for i in df.columns:
    print(i, ">>>>",df[i].nunique(),"nos")
# Out:
# Date >>>> 1442 nos
# Time >>>> 1440 nos
# Global_active_power >>>> 6534 nos
# Global_reactive_power >>>> 896 nos
# Voltage >>>> 5168 nos
# Global_intensity >>>> 377 nos
# Sub_metering_1 >>>> 153 nos
# Sub_metering_2 >>>> 145 nos
# Sub_metering_3 >>>> 32 nos

# %%
## All the features are numerical

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %%
#Data type conversion 
df["Date_converted"]=pd.to_datetime(df['Date'])
df
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# 2075257  26/11/2010  21:01:00               0.934                   0.0
# 2075258  26/11/2010  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# ...

# %%
change_dtype=['Global_active_power', 'Global_reactive_power',
       'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2']
for i in change_dtype:
    if "?" in df[i].unique():
        print(i)
# Out:
# Global_active_power
# Global_reactive_power
# Voltage
# Global_intensity
# Sub_metering_1
# Sub_metering_2

# %%
# Replacing The "?" with Np.nan Values 
df.replace("?",np.nan,inplace=True)

# %%
df.isna().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3           25979
# Date_converted               0
# Date_time                    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
# Changing the Data types from object to Float
for i in change_dtype:
    df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2049280 entries, 0 to 2075258
# Data columns (total 11 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    float64
#  3   Global_reactive_power  float64
#  4   Voltage                float64
#  5   Global_intensity       float64
#  6   Sub_metering_1         float64
#  7   Sub_metering_2         float64
#  8   Sub_metering_3         float64
#  9   Date_converted         datetime64[ns]
#  10  Date_time              datetime64[ns]
# dtypes: datetime64[ns](2), float64(7), object(2)
# memory usage: 187.6+ MB

# %%
# %time
# Create datetime Feature using Date and Time Column
df['Date_time']=df['Date'] + " " +df['Time']
df["Date_time"]=pd.to_datetime(df['Date_time'])
df
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#                Date      Time  Global_active_power  Global_reactive_power  \
# 0        16/12/2006  17:24:00                4.216                  0.418
# 1        16/12/2006  17:25:00                5.360                  0.436
# 2        16/12/2006  17:26:00                5.374                  0.498
# 3        16/12/2006  17:27:00                5.388                  0.502
# 4        16/12/2006  17:28:00                3.666                  0.528
# ...             ...       ...                  ...                    ...
# 2075254  26/11/2010  20:58:00                0.946                  0.000
# 2075255  26/11/2010  20:59:00                0.944                  0.000
# 2075256  26/11/2010  21:00:00                0.938                  0.000
# 2075257  26/11/2010  21:01:00                0.934                  0.000
# 2075258  26/11/2010  21:02:00                0.932                  0.000
#
# ...

# %%
# %time
# Drop the Duplicated Entries if any 
#df[df.duplicated()]

df.drop_duplicates()
#No duplicates are their in the dataset
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#                Date      Time  Global_active_power  Global_reactive_power  \
# 0        16/12/2006  17:24:00                4.216                  0.418
# 1        16/12/2006  17:25:00                5.360                  0.436
# 2        16/12/2006  17:26:00                5.374                  0.498
# 3        16/12/2006  17:27:00                5.388                  0.502
# 4        16/12/2006  17:28:00                3.666                  0.528
# ...             ...       ...                  ...                    ...
# 2075254  26/11/2010  20:58:00                0.946                  0.000
# 2075255  26/11/2010  20:59:00                0.944                  0.000
# 2075256  26/11/2010  21:00:00                0.938                  0.000
# 2075257  26/11/2010  21:01:00                0.934                  0.000
# 2075258  26/11/2010  21:02:00                0.932                  0.000
#
# ...

# %%
# %time
# Drop the Nan values 
df.dropna()
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#                Date      Time  Global_active_power  Global_reactive_power  \
# 0        16/12/2006  17:24:00                4.216                  0.418
# 1        16/12/2006  17:25:00                5.360                  0.436
# 2        16/12/2006  17:26:00                5.374                  0.498
# 3        16/12/2006  17:27:00                5.388                  0.502
# 4        16/12/2006  17:28:00                3.666                  0.528
# ...             ...       ...                  ...                    ...
# 2075254  26/11/2010  20:58:00                0.946                  0.000
# 2075255  26/11/2010  20:59:00                0.944                  0.000
# 2075256  26/11/2010  21:00:00                0.938                  0.000
# 2075257  26/11/2010  21:01:00                0.934                  0.000
# 2075258  26/11/2010  21:02:00                0.932                  0.000
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3', 'Date_converted', 'Date_time'],
#       dtype='object')

# %%
# %time
df['Total_meter_reading'] =df["Sub_metering_1"] + df['Sub_metering_2'] +df['Sub_metering_3']
df.head()
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#          Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00                4.216                  0.418   234.84
# 1  16/12/2006  17:25:00                5.360                  0.436   233.63
# 2  16/12/2006  17:26:00                5.374                  0.498   233.29
# 3  16/12/2006  17:27:00                5.388                  0.502   233.74
# 4  16/12/2006  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0
#
# ...

# %%
df.to_csv("Data\Cleaned_data.csv",index=False)
